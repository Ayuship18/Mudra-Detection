# %%
from ultralytics import YOLO

model = YOLO("/Users/ayushipradhan/MudraDetection/runs/detect/runs/mudra_yolov8n/weights/best.pt")

results = model("/Users/ayushipradhan/MudraDetection/mudra_data/test/images/1_jpg.rf.0e888ec920e439c2fd2127ee9c8f88ac.jpg")

results[0].show()
# Out:
# image 1/1 /Users/ayushipradhan/MudraDetection/mudra_data/test/images/1_jpg.rf.0e888ec920e439c2fd2127ee9c8f88ac.jpg: 384x640 1 mushti, 64.3ms
# Speed: 3.6ms preprocess, 64.3ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 640)
